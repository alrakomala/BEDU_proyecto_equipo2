# %% [markdown]
# ## **Uso de APIs**

# %% [markdown]
# Aquí se instalan las librerías necesarias para hacer el llamado a la API y hacer la colección en un Data Frame de alguna emisora introduciendo su ticker, por ejemplo GOOGL para Google A, META para Facebook, AAPL para Apple, etc.

# %%
# !pip install alpha_vantage
import pandas as pd
import requests
from alpha_vantage.timeseries import TimeSeries
import time

api_key = 'L6HBXMRZ40ARG9RN'

from alpha_vantage.timeseries import TimeSeries
from pprint import pprint
ts = TimeSeries(key = api_key, output_format = 'pandas', indexing_type = 'date')
print("Consulta el ticker de la emisora que deseas en https://www.bmv.com.mx/es/emisoras/informacion-de-emisoras.")
ticker = str(input('Teclea el ticker de la emisora: '))  # entrada del ticker
data, meta_data = ts.get_intraday(symbol = ticker, interval = '60min', outputsize = 'full')
data = data.sort_index()
data
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Consulta el ticker de la emisora que deseas en https://www.bmv.com.mx/es/emisoras/informacion-de-emisoras.
# Teclea el ticker de la emisora: googl
#                      1. open  2. high  3. low  4. close   5. volume
# date
# 2022-12-15 05:00:00   93.730   93.740   93.25     93.52     11750.0
# 2022-12-15 06:00:00   93.510   93.570   93.20     93.27     12114.0
# 2022-12-15 07:00:00   93.310   93.940   93.26     93.65     13476.0
# 2022-12-15 08:00:00   93.650   93.760   93.41     93.74     25034.0
# 2022-12-15 09:00:00   93.610   94.833   93.00     93.23    128065.0
# ...                      ...      ...     ...       ...         ...
# 2023-02-08 16:00:00   99.705   99.720   98.96     99.40  10352718.0
# 2023-02-08 17:00:00   99.370   99.640   99.12     99.40   1620626.0
# 2023-02-08 18:00:00   99.400   99.450   99.20     99.30    114684.0
# ...

# %% [markdown]
# Aquí se guarda la información en un archivo .csv

# %%
data.to_csv('/content/drive/MyDrive/BEDU_2023/Proyecto/data_emisora.csv') # guardar en archivo
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ----

# %% [markdown]
# Aquí se instalan las librerías necesarias para hacer el llamado a la API y hacer la colección en un Data Frame del Bitcoin.

# %%
from alpha_vantage.cryptocurrencies import CryptoCurrencies
import matplotlib.pyplot as plt

# %%
cripto = CryptoCurrencies(key = api_key, output_format = 'pandas')
data2, meta_data = cripto.get_digital_currency_daily(symbol = 'BTC', market = 'USD')
data2 = data2.sort_index()
data2
# Out:
#             1a. open (USD)  1b. open (USD)  2a. high (USD)  2b. high (USD)  \
# date
# 2020-05-16         9315.96         9315.96         9588.00         9588.00
# 2020-05-17         9380.81         9380.81         9888.00         9888.00
# 2020-05-18         9681.11         9681.11         9950.00         9950.00
# 2020-05-19         9733.93         9733.93         9897.21         9897.21
# 2020-05-20         9775.13         9775.13         9842.00         9842.00
# ...                    ...             ...             ...             ...
# 2023-02-05        23327.66        23327.66        23433.33        23433.33
# 2023-02-06        22932.91        22932.91        23158.25        23158.25
# 2023-02-07        22762.52        22762.52        23350.25        23350.25
# 2023-02-08        23242.42        23242.42        23452.00        23452.00
# 2023-02-09        22961.85        22961.85        23011.39        23011.39
#
# ...

# %% [markdown]
# Aquí se guarda la información en un archivo .csv

# %%
from google.colab import drive
drive.mount('/content/drive')
data2.to_csv('/content/drive/MyDrive/BEDU_2023/Proyecto/data_cripto.csv') # guardar en archivo
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Aquí se grafica

# %%
parameters = {'axes.labelsize': 25,
          'axes.titlesize': 30,
          'xtick.labelsize': 15,
          'ytick.labelsize': 15}
plt.rcParams.update(parameters)

plt.figure(figsize=(15,10))
data2['4a. close (USD)'].plot()
plt.tight_layout()
plt.title('Precio de cierre diario para el bitcoin (BTC)')
plt.xlabel('Fechas')
plt.ylabel('Precio o Valor en Dólares')
plt.grid()
plt.show()
